# %%
# Library dan modul tambahan dimuat
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# Membaca file CSV
df=pd.read_csv('/content/email.csv')

# Menampilkan 5 baris terakhir dari dataset
df.tail()

# Menghapus baris terakhir (jika kosong)
df = df.iloc[:-1, :]

# Menampilkan 5 baris terakhir setelah modifikasi
df.tail()

# Menampilkan jumlah nilai null dalam dataset
df.isnull().sum()

# Menampilkan jumlah data duplikat dalam dataset
df.duplicated().sum()

# Menghapus data duplikat
df.drop_duplicates(inplace=True)

# Menampilkan jumlah data duplikat setelah penghapusan
df.duplicated().sum()

# Menghapus nilai null (jika ada)
df.dropna(inplace=True)

# Menampilkan ukuran dataset
df.shape

# Menentukan atribut 'Message' sebagai variabel X
X=df['Message']

# Menampilkan 5 baris pertama dari variabel X
X.head()

# Menentukan label 'Category' sebagai variabel y
y=df['Category']

# Menampilkan 5 baris pertama dari variabel y
y.head()

# Mengganti label 'spam' dengan 1 dan 'ham' dengan 0 dalam kolom 'Category'
df['Category'].replace({'spam': 1, 'ham': 0}, inplace=True)

# Menampilkan 5 baris pertama dari variabel y setelah penggantian
y.head()

# Pembagian dataset menjadi data latih dan data uji
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import seaborn as sns
# %matplotlib inline

# Menggunakan CountVectorizer
cv=CountVectorizer()
# atau bisa menggunakan TfidfVectorizer dengan beberapa parameter tambahan
# cv=TfidfVectorizer(ngram_range=(1,3),max_features=10)

# Memisahkan data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=34)

# Menampilkan ukuran data latih
X_train.shape

# Menampilkan 5 baris pertama dari data latih
X_train.head()

# Melakukan proses tokenisasi dan transformasi dengan CountVectorizer
X_trains_t=cv.fit_transform(X_train)
X_test_t=cv.transform(X_test)

# Menampilkan hasil transformasi
print(X_trains_t)

# Menggunakan DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix

# Mengganti LogisticRegression dengan DecisionTreeClassifier
model = DecisionTreeClassifier()

# Menampilkan jumlah nilai unik dalam y_train
unique_values = y_train.value_counts()
print(unique_values)

# Melatih model
model.fit(X_trains_t, y_train)

# Melakukan prediksi
y_pred = model.predict(X_test_t)

# Menghitung dan menampilkan metrik evaluasi
acc = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(conf_matrix)
print("Akurasi model:", acc)
print("Skor presisi:", precision_score(y_test, y_pred))
print("Skor recall:", recall_score(y_test, y_pred))
print("Skor F1:", f1_score(y_test, y_pred))
# Out:
#   (0, 7068)	1
#   (0, 6836)	1
#   (0, 4042)	1
#   (0, 1191)	1
#   (0, 889)	2
#   (0, 7113)	1
#   (0, 2246)	1
#   (0, 6360)	1
#   (0, 3588)	1
#   (0, 5738)	1
#   (0, 1930)	1
#   (0, 1228)	1
#   (0, 3576)	1
#   (0, 4388)	1
#   (0, 1685)	1
#   (0, 6702)	1
#   (0, 7026)	1
#   (0, 4667)	1
#   (0, 5834)	1
#   (0, 2089)	1
#   (0, 774)	1
#   (0, 1563)	1
#   (0, 4080)	1
#   (0, 3749)	1
#   (0, 4151)	1
#   :	:
#   (3864, 782)	1
#   (3864, 2323)	1
#   (3864, 7293)	1
#   (3864, 5945)	1
#   (3864, 1771)	1
#   (3864, 1083)	1
#   (3864, 6588)	1
#   (3864, 5956)	1
#   (3864, 4396)	1
#   (3864, 5918)	1
#   (3865, 4609)	1
#   (3865, 7010)	1
#   (3865, 705)	1
#   (3865, 7286)	1
#   (3865, 1683)	1
#   (3866, 3106)	1
#   (3866, 3727)	1
#   (3866, 5342)	1
#   (3866, 4480)	1
#   (3866, 3128)	1
#   (3866, 1149)	1
#   (3866, 3377)	1
#   (3866, 7299)	1
#   (3866, 4876)	1
#   (3866, 2494)	1
# 0    3392
# 1     475
# Name: Category, dtype: int64
# Confusion Matrix:
# [[1106   18]
#  [  24  142]]
# ...
